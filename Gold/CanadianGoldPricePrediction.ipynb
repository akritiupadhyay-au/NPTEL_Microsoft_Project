# %% [markdown]
# ## Importing Libraries

# %%
# %pip install -q seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv("Gold Price.csv")
data.head()
# Out:
#          Name US dollar    Euro Japanese yen Pound Sterling Canadian dollar  \
# 0  12/29/1978    226.00  137.10          NaN         110.70             NaN
# 1    1/1/1979    226.00  137.10          NaN         110.70             NaN
# 2    2/1/1979    226.80  137.30    43,164.90         111.50          263.70
# 3    3/1/1979    218.60  134.00    43,717.90         108.00          264.40
# 4    4/1/1979    223.20  136.80    43,674.90         110.70          264.10
#
#   Swiss franc Indian rupee Chinese renmimbi Turkish lira Saudi riyal  \
# 0         NaN          NaN              NaN          NaN         NaN
# 1         NaN          NaN              NaN          NaN         NaN
# 2      359.60     1,792.90              NaN          NaN      735.60
# 3      365.90     1,802.20              NaN          NaN      739.40
# 4      366.40     1,811.70              NaN          NaN      743.40
#
#   Indonesian rupiah UAE dirham Thai baht Vietnamese dong Egyptian pound  \
# 0               NaN        NaN       NaN             NaN            NaN
# 1               NaN        NaN       NaN             NaN            NaN
# 2        138,160.50     851.30  4,454.60             NaN            NaN
# 3        138,877.00     855.70  4,477.70             NaN            NaN
# 4        139,616.30     860.30  4,501.50             NaN            NaN
#
#    Korean won Russian ruble South African rand Australian dollar
# 0         NaN           NaN                NaN               NaN
# 1         NaN           NaN                NaN               NaN
# 2  107,470.00           NaN             194.60            193.60
# 3  108,027.40           NaN             192.20            193.00
# 4  108,602.50           NaN             193.00            194.60

# %%
data.shape
# Out:
# (11677, 20)

# %% [markdown]
# ## Null Data

# %%
nulldata = data.isnull().sum()
nulldata[nulldata>0]
# Out:
# Japanese yen             2
# Canadian dollar          2
# Swiss franc              2
# Indian rupee             2
# Chinese renmimbi      1571
# Turkish lira          1045
# Saudi riyal              2
# Indonesian rupiah        2
# UAE dirham               2
# Thai baht                2
# Vietnamese dong       2851
# Egyptian pound        2591
# Korean won               2
# Russian ruble         3661
# South African rand       2
# Australian dollar        2
# dtype: int64

# %%
data = data.rename(columns = {"Name":"Date"})
data = data.dropna()
data.head()
# Out:
#            Date US dollar    Euro Japanese yen Pound Sterling Canadian dollar  \
# 3661  11/1/1993    328.40  264.60    41,063.30         211.40          419.30
# 3662  12/1/1993    329.20  266.10    41,256.90         213.80          420.20
# 3663  1/13/1993    327.60  265.20    41,276.20         212.80          420.40
# 3664  1/14/1993    327.70  263.40    41,182.70         213.10          418.70
# 3665  1/15/1993    327.70  265.10    41,337.30         214.20          419.80
#
#      Swiss franc Indian rupee Chinese renmimbi Turkish lira Saudi riyal  \
# 3661      489.40     9,447.20         1,864.20         2.90    1,232.90
# 3662      493.30     9,526.50         1,885.10         2.90    1,238.90
# 3663      488.80     9,478.60         1,876.30         2.90    1,233.30
# 3664      485.40     9,477.90         1,879.30         2.90    1,232.10
# 3665      490.50     9,507.60         1,888.80         2.90    1,233.30
#
#      Indonesian rupiah UAE dirham Thai baht Vietnamese dong Egyptian pound  \
# 3661        678,984.20   1,207.40  8,322.60    3,501,319.60       1,072.20
# 3662        686,604.20   1,214.10  8,413.80    3,540,613.90       1,099.50
# 3663        679,859.60   1,207.90  8,378.60    3,524,014.10       1,093.50
# 3664        683,512.40   1,206.60  8,417.70    3,529,676.20       1,093.00
# 3665        682,063.70   1,207.80  8,383.10    3,547,517.40       1,093.40
#
#       Korean won Russian ruble South African rand Australian dollar
# 3661  258,497.60        132.70           1,012.60            488.90
# 3662  262,333.90        134.20           1,011.70            488.40
# 3663  259,550.80        133.60           1,011.30            487.70
# 3664  261,507.50        133.80           1,009.20            490.50
# 3665  260,896.30        134.50           1,010.70            488.00

# %% [markdown]
# ## Datetime Extraction

# %%
data['Date'] = pd.to_datetime(data['Date'],format = "%m/%d/%Y")
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['Day'] = data['Date'].dt.day
data.tail()
# Out:
#             Date US dollar      Euro Japanese yen Pound Sterling  \
# 11672 2023-09-26  1,907.10  1,804.40   284,017.00       1,566.90
# 11673 2023-09-27  1,887.30  1,796.90   282,377.80       1,556.50
# 11674 2023-09-28  1,873.60  1,774.50   279,702.30       1,535.70
# 11675 2023-09-29  1,870.50  1,768.30   279,471.40       1,532.40
# 11676 2023-02-10  1,870.50  1,768.30   279,471.40       1,532.40
#
#       Canadian dollar Swiss franc Indian rupee Chinese renmimbi Turkish lira  \
# 11672        2,576.60    1,744.20   158,862.00        13,942.80    51,982.20
# 11673        2,551.10    1,737.30   157,100.00        13,793.00    51,542.00
# 11674        2,526.50    1,716.90   155,765.10        13,673.20    51,373.50
# 11675        2,533.60    1,710.60   155,445.80        13,650.90    51,294.90
# 11676        2,533.60    1,710.60   155,445.80        13,650.90    51,294.90
#
#        ...  Thai baht Vietnamese dong Egyptian pound    Korean won  \
# 11672  ...  69,510.10   46,499,600.20      58,977.40  2,579,914.50
# 11673  ...  69,262.00   46,040,683.50      58,307.00  2,562,934.50
# 11674  ...  68,527.00   45,714,620.00      57,886.70  2,530,660.20
# 11675  ...  68,407.90   45,518,617.50      57,796.00  2,523,098.80
# 11676  ...  68,407.90   45,518,617.50      57,796.00  2,523,098.80
#
#       Russian ruble South African rand Australian dollar  Year Month Day
# 11672    185,121.50          36,346.70          2,977.00  2023     9  26
# 11673    182,828.00          36,254.50          2,969.80  2023     9  27
# 11674    181,380.10          35,614.90          2,916.90  2023     9  28
# 11675    180,724.30          35,342.20          2,904.10  2023     9  29
# 11676    180,724.30          35,342.20          2,904.10  2023     2  10
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Separating the data of 10 years from now

# %%
data10 = data[(data['Year']>2013)]
data10.shape
# Out:
# (2544, 23)

# %%
columns_to_convert = data10.columns[1:20]
data10[columns_to_convert] = data10[columns_to_convert].apply(lambda series: series.str.replace(',', '').astype(float))
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2544 entries, 9133 to 11676
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                2544 non-null   datetime64[ns]
#  1   US dollar           2544 non-null   float64
#  2   Euro                2544 non-null   float64
#  3   Japanese yen        2544 non-null   float64
#  4   Pound Sterling      2544 non-null   float64
#  5   Canadian dollar     2544 non-null   float64
#  6   Swiss franc         2544 non-null   float64
#  7   Indian rupee        2544 non-null   float64
#  8   Chinese renmimbi    2544 non-null   float64
#  9   Turkish lira        2544 non-null   float64
#  10  Saudi riyal         2544 non-null   float64
#  11  Indonesian rupiah   2544 non-null   float64
#  12  UAE dirham          2544 non-null   float64
#  13  Thai baht           2544 non-null   float64
#  14  Vietnamese dong     2544 non-null   float64
#  15  Egyptian pound      2544 non-null   float64
#  16  Korean won          2544 non-null   float64
#  17  Russian ruble       2544 non-null   float64
#  18  South African rand  2544 non-null   float64
#  19  Australian dollar   2544 non-null   float64
#  20  Year                2544 non-null   int32
#  21  Month               2544 non-null   int32
#  22  Day                 2544 non-null   int32
# dtypes: datetime64[ns](1), float64(19), int32(3)
# memory usage: 447.2 KB

# %%
dataCanada = data10[['Date','Year','Month','Day','Canadian dollar']]
dataCanada.shape
# Out:
# (2544, 5)

# %%
dataCanada.head()
# Out:
#            Date  Year  Month  Day  Canadian dollar
# 9133 2014-01-01  2014      1    1           1282.7
# 9134 2014-02-01  2014      2    1           1303.4
# 9135 2014-03-01  2014      3    1           1309.8
# 9136 2014-06-01  2014      6    1           1327.1
# 9137 2014-07-01  2014      7    1           1319.7

# %%
dataCanada.isnull().sum()
# Out:
# Date               0
# Year               0
# Month              0
# Day                0
# Canadian dollar    0
# dtype: int64

# %%
plt.subplots(figsize = (15,5))
sns.lineplot(dataCanada,x = dataCanada['Date'], y = dataCanada['Canadian dollar'])
plt.show()

# %%
years = list(dataCanada['Year'].value_counts().index.sort_values())
years
# Out:
# [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %% [markdown]
# ## Helper function for collecting and plotting data of each year after separation

# %%
def Yearly_data(year):
    grp = dataCanada[(dataCanada.Year == year)]
    plt.subplots(figsize = (20,5))
    sns.lineplot(grp,x = grp.Month, y = grp['Canadian dollar'])
    plt.title(f'Year {year}')
    plt.show()

# %%
for i in range(len(years)):
    Yearly_data(years[i])

# %%
dataCanada.head()
# Out:
#            Date  Year  Month  Day  Canadian dollar
# 9133 2014-01-01  2014      1    1           1282.7
# 9134 2014-02-01  2014      2    1           1303.4
# 9135 2014-03-01  2014      3    1           1309.8
# 9136 2014-06-01  2014      6    1           1327.1
# 9137 2014-07-01  2014      7    1           1319.7

# %% [markdown]
# ## Let's Try Prophet

# %%
from sklearn.model_selection import train_test_split
x = dataCanada[['Year','Month','Day']]
y = dataCanada[['Canadian dollar']]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 99)

# %% [markdown]
# ## Importing model

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# ## Helper function for model evaluation

# %%
def evaluation_metrics(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test,y_pred)
    r2score = r2_score(y_test,y_pred)
    trainscore = model.score(x_train,y_train)
    
    print(f'Mean Squared Error = {mse}')
    print(f'Mean Absolute Error = {mae}')
    print(f'Root Mean Squared Error = {rmse}')
    print(f'r2 score = {r2score}')
    
    Comparison = x_test.copy("deep")
    Comparison['Actual Price'] = y_test
    Comparison['Predicted Price'] = y_pred
    
    sns.lineplot(Comparison, x = 'Year',y = 'Actual Price')
    sns.lineplot(Comparison, x = 'Year',y = 'Predicted Price')
    plt.legend(['Actual Price','','Predicted Price'])
    plt.show()
    
    return {'Training Score': trainscore,
           'Testing Score': r2score}

# %%
results = {}

# %% [markdown]
# ## Random Forest Regressor

# %%
results['Random Forest Regressor'] = evaluation_metrics(rfr)
# Out:
# Mean Squared Error = 531.3662266188608
# Mean Absolute Error = 15.928555992141447
# Root Mean Squared Error = 23.051382314708608
# r2 score = 0.9967919308053684

# %% [markdown]
# ## Checking Overfitting

# %%
resultsdf = pd.DataFrame(results)
resultsdf
# Out:
#                 Random Forest Regressor
# Testing Score                  0.996792
# Training Score                 0.999399

# %%
# %pip install -q prophet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Making time dataframe for Prophet

# %%
time_data = dataCanada[['Date','Canadian dollar']]
time_data.columns = ['ds','y']
time_data.head()
# Out:
#              ds       y
# 9133 2014-01-01  1282.7
# 9134 2014-02-01  1303.4
# 9135 2014-03-01  1309.8
# 9136 2014-06-01  1327.1
# 9137 2014-07-01  1319.7

# %%
from prophet import Prophet
m = Prophet(daily_seasonality=True)
model_fit = m.fit(time_data)
# Out:
# Importing plotly failed. Interactive plots will not work.
# 14:16:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:29 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = model_fit.predict(time_data)
forecast[['ds','yhat','yhat_upper','yhat_lower']].tail()
# Out:
#              ds         yhat   yhat_upper   yhat_lower
# 2539 2023-12-04  2590.929668  2691.468994  2485.169783
# 2540 2023-12-05  2591.778741  2697.498406  2483.769462
# 2541 2023-12-06  2586.818551  2687.746001  2487.033312
# 2542 2023-12-07  2591.470684  2701.864255  2487.136669
# 2543 2023-12-09  2580.811238  2687.500832  2474.919589

# %%
model_fit.plot(forecast);

# %%
model_fit.plot_components(forecast);

# %% [markdown]
# ## Forecasting for next 6 months

# %%
m2 = Prophet(daily_seasonality=True)
m2.fit(time_data)
future = m2.make_future_dataframe(periods = 336)
future.tail(10)
# Out:
# 14:16:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:33 - cmdstanpy - INFO - Chain [1] done processing
#              ds
# 2870 2024-10-31
# 2871 2024-11-01
# 2872 2024-11-02
# 2873 2024-11-03
# 2874 2024-11-04
# 2875 2024-11-05
# 2876 2024-11-06
# 2877 2024-11-07
# 2878 2024-11-08
# 2879 2024-11-09

# %%
forecast2 = m2.predict(future)
forecast2[['ds','yhat','yhat_upper','yhat_lower']].tail()
# Out:
#              ds         yhat   yhat_upper   yhat_lower
# 2875 2024-11-05  2783.678685  2965.363983  2587.557720
# 2876 2024-11-06  2779.181129  2961.530337  2581.427178
# 2877 2024-11-07  2784.197970  2962.357625  2596.998722
# 2878 2024-11-08  2780.088214  2955.825332  2597.546510
# 2879 2024-11-09  2773.792384  2952.559409  2584.372794

# %%
m2.plot(forecast2);

# %%
m2.plot_components(forecast2);

# %%
predictions = forecast2[['ds','yhat']]
predictions = predictions.rename(columns = {'ds':'Date','yhat':'Canadian dollar'})
predictions.head()
# Out:
#         Date  Canadian dollar
# 0 2014-01-01      1371.292730
# 1 2014-01-04      1374.551852
# 2 2014-01-05      1394.520974
# 3 2014-01-07      1390.162560
# 4 2014-01-08      1386.732393

# %%
plt.subplots(figsize = (15,8))
sns.lineplot(time_data,x = 'ds',y='y',legend='full')
sns.lineplot(predictions,x = 'Date',y = 'Canadian dollar',legend='full')
plt.legend(labels = ['Actual','','Prediction'])
plt.show()

# %%
predictions['Date'] = pd.to_datetime(predictions['Date'])
predictions['Year'] = predictions['Date'].dt.year
predictions['Month'] = predictions['Date'].dt.month
predictions['Day'] = predictions['Date'].dt.day

# %% [markdown]
# ## Model Evaluation

# %%
x_time  = predictions.drop(columns=['Date','Canadian dollar'])
y_time = predictions[['Canadian dollar']]

# %%
x_time_train,x_time_test,y_time_train,y_time_test = train_test_split(x_time,y_time,test_size=0.2,random_state=99)

# %%
rfr_time_model = RandomForestRegressor()
rfr_time_model.fit(x_time_train,y_time_train)
rfr_time_pred = rfr_time_model.predict(x_time_test)

# %%
results['Random Forest Evaluation Regressor'] = evaluation_metrics(rfr_time_model)
# Out:
# Mean Squared Error = 530.7628169980359
# Mean Absolute Error = 15.96036935166998
# Root Mean Squared Error = 23.038290235997025
# r2 score = 0.9967955738291802

# %% [markdown]
# ## Comparing accuracy of predicted model and forecasted model

# %%
CompareRFR = pd.DataFrame(results)
CompareRFR
# Out:
#                 Random Forest Regressor  Random Forest Evaluation Regressor
# Training Score                 0.999399                            0.999408
# Testing Score                  0.996792                            0.996796

# %%
analysis = predictions[predictions['Year']>2022]

plt.subplots(figsize = (15,5))
plt.plot(analysis['Date'],analysis['Canadian dollar'],color = 'red')
plt.show()
# Out:
# Bad pipe message: %s [b'\x85I\xcc\xd5}Z\x04H\xc9Nt\x83\xa1\xd6Q2\x04\xfa \xecv\xa5L\xab\xd07\t\xb1\xab\x8e\xd8\x0eaCV\xe6\xa7h\xbf\xca\xb5\xf4\x01O\x0f+\x18\xac\xe6}s\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \xe8+\xe7\x96\xa2qU\xdd\xb7\xa4\xb0\xb5\xeez\x0fz\xe8\xba*\xb6\x7f\x1a6']
# Bad pipe message: %s [b"\x89-\x18hQuWd\xdeXS/\xe5s\x00\xfe\xc1q\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02"]
# Bad pipe message: %s [b'\x02']
# Bad pipe message: %s [b'g\xc4S~\xf7\x9e\xa1P\xce\xa3\xce\xf7\x7fe\xe4\x18\xa2\xd7\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc', b"\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t"]
# Bad pipe message: %s [b'7.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'\x11\x8d>\x04\xdb\xfe\xf3\x8b=t\xa1Xg\n\x05\x98&\x94\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00']
# Bad pipe message: %s [b'\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01\x15\x03\x02']
# Bad pipe message: %s [b'\xc4\xb9\xbb\xb1+\xd8K=b\r\xfe\xf2\xdb\xc6o\x83\xba~\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0', b'/\x00\x9a']
# Bad pipe message: %s [b'\xa6\xe6\x87\xf2\x02A\xd4,\xccbO\x978\x01\x0cUh\xca\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00']
# Bad pipe message: %s [b'\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12']
# Bad pipe message: %s [b"f\x9a\x93n\xbb\xcc\xe6\x12,3u\x94\xb8\xfd\xd4#\x94\x08\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00"]
# Bad pipe message: %s [b'\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'\xcc(\x1b\xa4X\xd7}\x9c\xa4 kL\xaa\xad"\xdeK\x9b\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0\'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03']
